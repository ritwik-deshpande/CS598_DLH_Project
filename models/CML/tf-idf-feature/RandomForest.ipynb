# %%
from sklearn.ensemble import RandomForestClassifier
import os
os.chdir('/Users/renalkakhan/Documents/GitHub/CS598_DLH_Project/')
from dataset.preprocessing.data_preprocessing import DataPreprocessing
from dataset.preprocessing.tf_idf_all_feature_matrix_gen import TFIDFFeatureGeneration
from dataset.preprocessing.word2vec_embeddings_gen import Word2VecFeatureGeneration
from sklearn.metrics import f1_score
import numpy as np
from sklearn.model_selection import StratifiedKFold
from sklearn.model_selection import KFold
import csv

# %%
class RandomForest:
    def __init__(self, x_train, y_train, x_test, y_test):
        self.rf = RandomForestClassifier(n_estimators=100, random_state=42)
        self.x_train = x_train
        self.y_train = y_train
        self.x_test = x_test
        self.y_test = y_test
        print(self.x_train.shape, self.y_train.shape, self.x_test.shape, self.y_test.shape)
        
    def train(self):
        self.rf.fit(self.x_train, self.y_train)

    def test_and_evaluate(self):
        y_pred = self.rf.predict(self.x_test)
        f1_macro = f1_score(self.y_test, y_pred, average='macro')
        f1_micro = f1_score(self.y_test, y_pred, average='micro')
        #print(f"Macro F1 score: {f1_macro} and Micro F1 Score {f1_micro}")
        return f1_macro, f1_micro

# %%
morbidities = ['Asthma', 'CAD', 'CHF', 'Depression', 'Diabetes', 'Gallstones', 'GERD', 'Gout', 'Hypercholesterolemia', 'Hypertension', 'Hypertriglyceridemia', 'OA', 'Obesity', 'OSA', 'PVD', 'Venous Insufficiency']

# %%
column_headings = ["Morbidity Class", "RF_Macro F1", "RF_Micro F1"]

with open("performances.csv", "w", newline="") as file:
    writer = csv.writer(file)

    # write the RF heading and the subheadings for Micro F1 and Macro F1
    writer.writerow([column_headings[0], column_headings[1], column_headings[2]])
    
for morbidity in morbidities:
    dataPreprocessing = DataPreprocessing('./dataset/train/train_data_textual.csv', morbidity)
    train_preprocessed_df = dataPreprocessing.preprocess_data()

    dataPreprocessing = DataPreprocessing('./dataset/test/test_data_textual.csv', morbidity)
    test_preprocessed_df = dataPreprocessing.preprocess_data()

    X, Y, words = TFIDFFeatureGeneration(train_preprocessed_df, morbidity).tf_idf_matrix_gen()

    # add KFold cross validation
    skf = KFold(n_splits=10, shuffle=True, random_state=42)

    f1_macro_list = []
    f1_micro_list = []
    for train_idx, val_idx in skf.split(X, Y):
        X_train_fold, Y_train_fold = X[train_idx], Y[train_idx]
        X_val_fold, Y_val_fold = X[val_idx], Y[val_idx]

        # Training RF using TF-IDF Representation
        rf_obj = RandomForest(X_train_fold, Y_train_fold, X_val_fold, Y_val_fold)
        rf_obj.train()

        f1_macro, f1_micro = rf_obj.test_and_evaluate()

        f1_macro_list.append(f1_macro)
        f1_micro_list.append(f1_micro)

    f1_macro = np.mean(f1_macro_list)
    f1_micro = np.mean(f1_micro_list)
    print(f"Macro F1 score: {f1_macro} and Micro F1 Score {f1_micro}")

    row_heading = morbidity

    # data to be written to the CSV file
    data = [f1_macro, f1_micro]

    with open("performances.csv", "a", newline="") as file:
        writer = csv.writer(file)
        row = [row_heading]
        row.extend(data)
        writer.writerow(row)
# Out:
# The shape of df is (76, 3)
# The shape of df is (70, 3)
# ['abd' 'abdoman' 'abdominal' 'about' 'above' 'acid' 'activity' 'acute'
#  'add' 'addition' 'additional' 'admission' 'admit' 'advair' 'afebrile'
#  'affect' 'after' 'air' 'albuterol' 'alcohol' 'alert' 'all' 'allergy'
#  'also' 'although' 'am' 'an' 'and' 'anemia' 'antibiotic' 'anxiety' 'any'
#  'apnea' 'appear' 'applicable' 'appointment' 'approximate' 'artery' 'as'
#  'asa' 'aspiration' 'aspirin' 'associate' 'asthma' 'at' 'atenolol'
#  'atorvastatin' 'atrial' 'atrovent' 'attend' 'avoid' 'aware' 'back'
#  'baseline' 'batch' 'be' 'become' 'bed' 'before' 'bid' 'bilateral'
#  'bilaterally' 'blocker' 'blood' 'both' 'bowel' 'bp' 'breath' 'brief' 'bs'
#  'bun' 'but' 'by' 'cad' 'calcium' 'call' 'can' 'cancer' 'cardiac'
#  'cardiology' 'cardiomyopathy' 'cardiovascular' 'care' 'cath'
#  'catheterization' 'cause' 'cc' 'cell' 'center' 'change' 'check' 'chest'
#  'chf' 'chill' 'chloride' 'cholesterol' 'chronic' 'clear' 'clinic' 'cm'
#  'coat' 'code' 'colace' 'colitis' 'comment' 'complete' 'complication'
#  'concern' 'condition' 'congestive' 'consistent' 'constipation' 'consult'
#  'cont' 'contingent' 'continue' 'control' 'copd' 'coronary' 'cough'
#  'coumadin' 'count' 'course' 'cp' 'creatinine' 'ct' 'culture' 'cv' 'cxr'
#  'daily' 'date' 'datum' 'day' 'decrease' 'demonstrate' 'deny' 'depression'
#  'develop' 'diabete' 'diabetes' 'diagnosis' 'diarrhea' 'diastolic'
#  'dictate' 'dictation' 'diet' 'diltiazem' 'dis' 'discharge' 'discontinue'
#  'disease' 'disposition' 'distress' 'diuresis' 'dm' 'do' 'doctor'
#  'document' 'dose' 'down' 'dr' 'draw' 'drop' 'drug' 'dry' 'due' 'during'
#  'dvt' 'dysfunction' 'dyspnea' 'echo' 'echocardiogram' 'ed' 'edema' 'ef'
#  'effusion' 'ejection' 'ekg' 'elevate' 'elevated' 'emergency' 'empty'
#  'end' 'enter' 'enteric' 'enzyme' 'episode' 'etiology' 'evaluation'
#  'every' 'evidence' 'exacerbation' 'exam' 'examination' 'exercise'
#  'extremity' 'failure' 'family' 'fat' 'feel' 'female' 'fever' 'final'
#  'find' 'flagyl' 'fluid' 'fluticasone' 'follow' 'food' 'foot' 'for'
#  'fraction' 'from' 'full' 'function' 'furosemide' 'further' 'gerd' 'gi'
#  'give' 'go' 'goal' 'good' 'gout' 'gram' 'grapefruit' 'great' 'have' 'hcl'
#  'he' 'head' 'headache' 'heart' 'heent' 'hematocrit' 'heparin' 'her'
#  'hernia' 'high' 'hip' 'his' 'history' 'ho' 'hold' 'home' 'hospital'
#  'hospitalization' 'hour' 'house' 'however' 'hr' 'htn' 'human' 'hx'
#  'hypertension' 'if' 'ii' 'illness' 'improve' 'in' 'include' 'increase'
#  'infarction' 'infection' 'infectious' 'information' 'inh' 'inhaler'
#  'initially' 'inr' 'instruct' 'instruction' 'insufficiency' 'insulin'
#  'intact' 'interaction' 'ipratropium' 'iron' 'ischemia' 'ischemic' 'it'
#  'iv' 'jvp' 'knee' 'know' 'lab' 'laboratory' 'lad' 'lasix' 'last' 'leave'
#  'left' 'leg' 'lesion' 'less' 'levofloxacin' 'likely' 'limit' 'lipitor'
#  'lisinopril' 'liter' 'lobe' 'lopressor' 'lovenox' 'low' 'lung' 'maintain'
#  'make' 'may' 'mcg' 'md' 'meal' 'med' 'medical' 'medication' 'mellitus'
#  'mental' 'meq' 'metoprolol' 'mg' 'mi' 'mibi' 'mild' 'minute' 'mitral'
#  'moderate' 'monitor' 'month' 'more' 'morphine' 'most' 'multiple' 'murmur'
#  'myocardial' 'nasal' 'nausea' 'nebulizer' 'neck' 'need' 'negative'
#  'neuro' 'neurological' 'new' 'nexium' 'nitroglycerin' 'nl' 'no' 'non'
#  'none' 'normal' 'not' 'notable' 'note' 'notice' 'now' 'nph' 'number'
#  'obese' 'obesity' 'obstructive' 'obtain' 'of' 'old' 'on' 'one' 'only'
#  'operation' 'or' 'oral' 'order' 'orient' 'orthopnea' 'osa' 'other'
#  'otherwise' 'out' 'outpatient' 'outpt' 'over' 'overridden' 'override'
#  'oxycodone' 'oxygen' 'pain' 'past' 'patient' 'pcp' 'pe' 'peak' 'pende'
#  'penicillin' 'per' 'physical' 'physician' 'place' 'plan' 'please' 'pm'
#  'pneumonia' 'po' 'positive' 'possible' 'post' 'postoperative' 'potassium'
#  'potentially' 'pre' 'prednisone' 'present' 'pressure' 'previous'
#  'primary' 'principal' 'prior' 'prn' 'problem' 'procedure' 'pt' 'puff'
#  'pulm' 'pulmonary' 'pulse' 'pump' 'qam' 'qd' 'qhs' 'qid' 'qpm' 'question'
#  'ra' 'rate' 'ray' 'reaction' 'reason' 'receive' 'recent' 'recently'
#  'recommend' 'ref' 'regimen' 'regular' 'rehab' 'release' 'renal' 'repair'
#  'repeat' 'report' 'require' 'resolve' 'respiratory' 'responsible'
#  'restart' 'result' 'resume' 'return' 'reveal' 'rhythm' 'right' 'room'
#  'rule' 'saturation' 'sc' 'scale' 'scan' 'schedule' 'secondary' 'see'
#  'seizure' 'serious' 'service' 'setting' 'several' 'severe' 'she'
#  'shortness' 'should' 'show' 'sign' 'significant' 'simvastatin' 'since'
#  'sinus' 'sit' 'skin' 'sleep' 'slide' 'slow' 'small' 'so' 'sob' 'social'
#  'sodium' 'soft' 'some' 'sound' 'st' 'stable' 'start' 'state' 'status'
#  'stay' 'stenosis' 'steroid' 'stomach' 'stool' 'stop' 'stress' 'study'
#  'subcutaneously' 'sugar' 'sulfa' 'sulfate' 'summary' 'surgery' 'swallow'
#  'symptom' 'systolic' 'tab' 'tablet' 'take' 'taper' 'team' 'temperature'
#  'tenderness' 'test' 'than' 'that' 'the' 'then' 'theophylline' 'therapy'
#  'there' 'these' 'this' 'three' 'throughout' 'tid' 'time' 'to' 'today'
#  'tolerate' 'toprol' 'total' 'tract' 'transfer' 'treat' 'treatment' 'tube'
#  'two' 'tylenol' 'undergo' 'unit' 'unless' 'until' 'up' 'upon' 'upper'
#  'urinary' 'urine' 'use' 'valve' 'vancomycin' 'vascular' 'ventricular'
#  'very' 'vital' 'volume' 'vomiting' 'walk' 'wall' 'warfarin' 'wave' 'wbc'
#  'we' 'week' 'weight' 'well' 'wheeze' 'wheezing' 'when' 'which' 'while'
#  'white' 'who' 'will' 'with' 'within' 'without' 'woman' 'work' 'worsen'
#  'would' 'wound' 'xl' 'year' 'yes' 'yo' 'you' 'your' 'zocor'] (76, 600) (76,)
# (68, 600) (68,) (8, 600) (8,)
# (68, 600) (68,) (8, 600) (8,)
# (68, 600) (68,) (8, 600) (8,)
# (68, 600) (68,) (8, 600) (8,)
# (68, 600) (68,) (8, 600) (8,)
# (68, 600) (68,) (8, 600) (8,)
# (69, 600) (69,) (7, 600) (7,)
# (69, 600) (69,) (7, 600) (7,)
# (69, 600) (69,) (7, 600) (7,)
# (69, 600) (69,) (7, 600) (7,)
# Macro F1 score: 0.9461538461538461 and Micro F1 Score 0.9857142857142858
# The shape of df is (349, 3)
# The shape of df is (299, 3)
# ['abdoman' 'abdominal' 'above' 'ace' 'acid' 'activity' 'acute' 'ada' 'add'
#  'addition' 'additional' 'admission' 'admit' 'afebrile' 'affect' 'after'
#  'ago' 'air' 'alcohol' 'alert' 'all' 'allergy' 'also' 'am' 'amiodarone'
#  'an' 'and' 'anemia' 'angina' 'angioplasty' 'anterior' 'antibiotic' 'any'
#  'aortic' 'appear' 'applicable' 'appointment' 'approximate'
#  'approximately' 'arm' 'artery' 'as' 'asa' 'aspirin' 'associate' 'at'
#  'atenolol' 'atorvastatin' 'atrial' 'attend' 'avoid' 'aware' 'back'
#  'baseline' 'batch' 'be' 'because' 'before' 'begin' 'bid' 'bilateral'
#  'bilaterally' 'bleed' 'block' 'blocker' 'blood' 'both' 'bowel' 'bp'
#  'breath' 'brief' 'bruit' 'bs' 'bun' 'but' 'by' 'bypass' 'cabg' 'cad'
#  'calcium' 'call' 'captopril' 'cardiac' 'cardiologist' 'cardiology'
#  'cardiomyopathy' 'cardiovascular' 'care' 'carotid' 'cath'
#  'catheterization' 'cause' 'cc' 'cell' 'center' 'change' 'check' 'chest'
#  'chf' 'chloride' 'cholesterol' 'chronic' 'circumflex' 'ck' 'clear'
#  'clinic' 'cm' 'coat' 'code' 'colace' 'comment' 'complete' 'complication'
#  'concern' 'condition' 'congestive' 'consistent' 'consult' 'contingent'
#  'continue' 'control' 'coronary' 'cough' 'coumadin' 'count' 'course' 'cp'
#  'creatinine' 'ct' 'culture' 'cv' 'cxr' 'daily' 'date' 'datum' 'day'
#  'decrease' 'demonstrate' 'deny' 'dependent' 'depression' 'descend'
#  'develop' 'diabete' 'diabetes' 'diagnosis' 'diarrhea' 'dictate'
#  'dictation' 'diet' 'digoxin' 'diltiazem' 'dis' 'discharge' 'discontinue'
#  'disease' 'disposition' 'distal' 'distress' 'diurese' 'diuresis' 'dm'
#  'do' 'doctor' 'document' 'dose' 'down' 'dr' 'draw' 'drop' 'drug' 'dry'
#  'due' 'during' 'dyspnea' 'echo' 'echocardiogram' 'ed' 'edema' 'ef'
#  'effusion' 'ejection' 'ekg' 'elevate' 'emergency' 'empty' 'end' 'enter'
#  'enteric' 'enzyme' 'episode' 'escription' 'evaluate' 'evaluation' 'every'
#  'evidence' 'exam' 'examination' 'exercise' 'exertion' 'extremity'
#  'failure' 'fall' 'family' 'fat' 'feel' 'female' 'fever' 'fibrillation'
#  'find' 'first' 'floor' 'fluid' 'follow' 'food' 'foot' 'for' 'four'
#  'fraction' 'from' 'full' 'function' 'furosemide' 'further' 'get' 'gi'
#  'give' 'glucose' 'go' 'good' 'graft' 'gram' 'grapefruit' 'great' 'have'
#  'hcl' 'hct' 'he' 'heart' 'heent' 'hematocrit' 'heparin' 'her' 'high'
#  'his' 'history' 'hold' 'home' 'hospital' 'hospitalization' 'hour' 'house'
#  'however' 'hr' 'htn' 'hypercholesterolemia' 'hypertension' 'if' 'ii'
#  'illness' 'improve' 'in' 'include' 'increase' 'index' 'infarction'
#  'infection' 'inferior' 'information' 'initially' 'inr' 'instruct'
#  'instruction' 'insufficiency' 'insulin' 'intact' 'interaction' 'iron'
#  'ischemia' 'ischemic' 'isordil' 'it' 'iv' 'jvp' 'knee' 'know' 'lab'
#  'laboratory' 'lad' 'lantus' 'lasix' 'last' 'lead' 'leave' 'left' 'leg'
#  'lesion' 'less' 'level' 'levofloxacin' 'likely' 'limit' 'lipitor'
#  'lisinopril' 'liter' 'live' 'long' 'lopressor' 'lovenox' 'low' 'lung'
#  'maintain' 'make' 'male' 'management' 'may' 'mcg' 'md' 'meal' 'med'
#  'medical' 'medication' 'mellitus' 'meq' 'metoprolol' 'mg' 'mi' 'mibi'
#  'mid' 'mild' 'minute' 'mitral' 'moderate' 'monitor' 'month' 'more'
#  'morning' 'most' 'mouth' 'mr' 'multiple' 'murmur' 'myocardial' 'nausea'
#  'neck' 'need' 'negative' 'neuro' 'new' 'nexium' 'next' 'night'
#  'nitroglycerin' 'no' 'non' 'none' 'normal' 'not' 'notable' 'note'
#  'notice' 'now' 'nph' 'number' 'obese' 'obtain' 'of' 'off' 'old' 'on'
#  'once' 'one' 'only' 'operation' 'or' 'order' 'orthopnea' 'other'
#  'otherwise' 'out' 'outpatient' 'over' 'overridden' 'override' 'oxygen'
#  'pacemaker' 'pack' 'pain' 'past' 'patient' 'pcp' 'pda' 'pe' 'per'
#  'perform' 'peripheral' 'physical' 'physician' 'place' 'placement' 'plan'
#  'platelet' 'plavix' 'please' 'pm' 'pneumonia' 'po' 'positive' 'possible'
#  'post' 'posterior' 'postop' 'postoperative' 'potassium' 'potentially'
#  'prednisone' 'present' 'pressure' 'previous' 'primary' 'principal'
#  'prior' 'prn' 'problem' 'procedure' 'proximal' 'pt' 'puff' 'pulmonary'
#  'pulse' 'pump' 'qam' 'qd' 'qhs' 'qpm' 'rate' 'ray' 'rca' 'reason'
#  'receive' 'recent' 'ref' 'regimen' 'regular' 'regurgitation'
#  'rehabilitation' 'release' 'remain' 'renal' 'repeat' 'report' 'require'
#  'resolve' 'respiratory' 'responsible' 'rest' 'restart' 'result' 'resume'
#  'return' 'reveal' 'rhythm' 'right' 'room' 'rule' 'saphenous' 'saturation'
#  'sc' 'scale' 'schedule' 'second' 'secondary' 'see' 'send' 'serious'
#  'service' 'several' 'severe' 'she' 'shortness' 'should' 'show' 'sign'
#  'significant' 'simvastatin' 'since' 'sinus' 'sit' 'slide' 'small' 'so'
#  'sob' 'social' 'sodium' 'soft' 'some' 'sound' 'st' 'stable' 'start'
#  'state' 'status' 'stay' 'stenosis' 'stent' 'stomach' 'stop' 'stress'
#  'study' 'subcutaneously' 'subsequently' 'sugar' 'summary' 'surgery'
#  'surgical' 'svg' 'symptom' 'system' 'systolic' 'tab' 'tablet' 'take'
#  'temperature' 'test' 'than' 'that' 'the' 'then' 'therapeutic' 'therapy'
#  'there' 'these' 'they' 'think' 'this' 'three' 'through' 'throughout'
#  'tid' 'time' 'to' 'today' 'tolerate' 'toprol' 'total' 'transfer' 'treat'
#  'treatment' 'troponin' 'tube' 'twice' 'two' 'undergo' 'unit' 'unless'
#  'until' 'up' 'upon' 'upper' 'urine' 'use' 'valve' 'vancomycin' 'vascular'
#  'vein' 'ventricular' 'very' 'vessel' 'vital' 'vitamin' 'volume'
#  'vomiting' 'walk' 'wall' 'warfarin' 'wave' 'we' 'week' 'weight' 'well'
#  'when' 'where' 'which' 'while' 'white' 'who' 'will' 'with' 'within'
#  'without' 'work' 'worsen' 'would' 'wound' 'xl' 'year' 'yes' 'you' 'your'
#  'zocor'] (349, 600) (349,)
# (314, 600) (314,) (35, 600) (35,)
# (314, 600) (314,) (35, 600) (35,)
# (314, 600) (314,) (35, 600) (35,)
# (314, 600) (314,) (35, 600) (35,)
# (314, 600) (314,) (35, 600) (35,)
# (314, 600) (314,) (35, 600) (35,)
# (314, 600) (314,) (35, 600) (35,)
# (314, 600) (314,) (35, 600) (35,)
# (314, 600) (314,) (35, 600) (35,)
# (315, 600) (315,) (34, 600) (34,)
# Macro F1 score: 0.48816449916461374 and Micro F1 Score 0.9540336134453782
# The shape of df is (246, 3)
# The shape of df is (216, 3)
# ['abd' 'abdominal' 'about' 'above' 'ace' 'acid' 'activity' 'acute' 'ada'
#  'add' 'addition' 'additional' 'admission' 'admit' 'afebrile' 'affect'
#  'afib' 'after' 'ago' 'air' 'albuterol' 'alert' 'all' 'allergy'
#  'allopurinol' 'also' 'am' 'amiodarone' 'an' 'and' 'anemia' 'antibiotic'
#  'any' 'aortic' 'appear' 'applicable' 'appointment' 'approximate'
#  'approximately' 'artery' 'as' 'asa' 'aspirin' 'asthma' 'at' 'atenolol'
#  'atorvastatin' 'atrial' 'attend' 'avoid' 'aware' 'back' 'baseline' 'be'
#  'because' 'bedtime' 'before' 'begin' 'beta' 'bid' 'bilateral'
#  'bilaterally' 'bleed' 'block' 'blocker' 'blood' 'both' 'bowel' 'bp'
#  'breath' 'brief' 'bs' 'bun' 'but' 'by' 'bypass' 'cabg' 'cad' 'calcium'
#  'call' 'captopril' 'cardiac' 'cardiologist' 'cardiology' 'cardiomyopathy'
#  'cardiovascular' 'care' 'carotid' 'cath' 'catheterization' 'cause' 'cc'
#  'cell' 'center' 'change' 'check' 'chest' 'chf' 'chill' 'chloride'
#  'chronic' 'clear' 'clinic' 'cm' 'code' 'colace' 'comment' 'complete'
#  'complication' 'concern' 'condition' 'congestive' 'consistent' 'consult'
#  'contingent' 'continue' 'control' 'copd' 'coronary' 'cough' 'coumadin'
#  'count' 'course' 'cr' 'crackle' 'creatinine' 'ct' 'culture' 'currently'
#  'cv' 'cxr' 'daily' 'date' 'datum' 'day' 'decrease' 'deny' 'depression'
#  'develop' 'diabete' 'diabetes' 'diagnosis' 'diarrhea' 'diastolic'
#  'dictate' 'dictation' 'diet' 'digoxin' 'dis' 'discharge' 'discontinue'
#  'disease' 'disposition' 'distress' 'diurese' 'diuresis' 'dm' 'do'
#  'doctor' 'document' 'dose' 'down' 'dr' 'draw' 'drip' 'drop' 'drug' 'dry'
#  'due' 'during' 'dysfunction' 'dyspnea' 'echo' 'echocardiogram' 'ed'
#  'edema' 'ef' 'effusion' 'ejection' 'ekg' 'elevate' 'elevated' 'emergency'
#  'empty' 'end' 'endocrine' 'enter' 'enzyme' 'episode' 'escription'
#  'evaluate' 'evaluation' 'every' 'evidence' 'exacerbation' 'exam'
#  'examination' 'exercise' 'exertion' 'extremity' 'failure' 'family' 'fat'
#  'feel' 'female' 'fever' 'fibrillation' 'find' 'first' 'fluid' 'follow'
#  'food' 'foot' 'for' 'four' 'fraction' 'from' 'full' 'function'
#  'furosemide' 'further' 'get' 'gi' 'give' 'glucose' 'go' 'goal' 'good'
#  'gout' 'graft' 'gram' 'great' 'have' 'hcl' 'hct' 'he' 'heart' 'heent'
#  'hematocrit' 'heme' 'heparin' 'her' 'high' 'his' 'history' 'hold' 'home'
#  'hospital' 'hospitalization' 'hour' 'house' 'however' 'hr' 'htn' 'hx'
#  'hypertension' 'if' 'ii' 'illness' 'improve' 'in' 'include' 'increase'
#  'infarction' 'infection' 'information' 'inhaler' 'inhibitor' 'initially'
#  'inr' 'instruct' 'instruction' 'insufficiency' 'insulin' 'intact'
#  'interaction' 'iron' 'ischemia' 'ischemic' 'isordil' 'it' 'iv' 'jvp'
#  'knee' 'know' 'lab' 'laboratory' 'lad' 'lantus' 'lasix' 'last' 'leave'
#  'left' 'leg' 'lesion' 'less' 'level' 'levofloxacin' 'likely' 'lipitor'
#  'lisinopril' 'liter' 'live' 'lopressor' 'lovenox' 'low' 'lung' 'maintain'
#  'make' 'may' 'mcg' 'md' 'meal' 'med' 'medical' 'medication' 'mellitus'
#  'meq' 'metoprolol' 'mg' 'mi' 'mid' 'mild' 'minute' 'mitral' 'moderate'
#  'monitor' 'month' 'more' 'most' 'mouth' 'mr' 'multiple' 'multivitamin'
#  'murmur' 'myocardial' 'nausea' 'neck' 'need' 'negative' 'neuro' 'new'
#  'nexium' 'next' 'night' 'nitroglycerin' 'no' 'non' 'none' 'normal' 'not'
#  'notable' 'note' 'notice' 'novolog' 'now' 'nph' 'number' 'obese'
#  'obesity' 'obtain' 'of' 'off' 'old' 'on' 'once' 'one' 'only' 'operation'
#  'or' 'order' 'orthopnea' 'other' 'otherwise' 'out' 'outpatient' 'over'
#  'overload' 'overridden' 'override' 'oxygen' 'pain' 'past' 'patient' 'pcp'
#  'pe' 'pende' 'penicillin' 'per' 'perform' 'peripheral' 'physical'
#  'physician' 'place' 'placement' 'plan' 'platelet' 'plavix' 'please' 'pm'
#  'pneumonia' 'po' 'poor' 'positive' 'possible' 'post' 'postop'
#  'postoperative' 'potassium' 'potentially' 'present' 'pressure' 'previous'
#  'primary' 'principal' 'prior' 'prn' 'problem' 'procedure' 'pt' 'puff'
#  'pulm' 'pulmonary' 'pulse' 'pump' 'qam' 'qd' 'qhs' 'qpm' 'ra' 'rate'
#  'ray' 'reason' 'receive' 'recent' 'recently' 'recommend' 'ref' 'regiman'
#  'regimen' 'regular' 'regurgitation' 'rehab' 'rehabilitation' 'release'
#  'remain' 'renal' 'repeat' 'replacement' 'report' 'require' 'resolve'
#  'respiratory' 'responsible' 'restart' 'restriction' 'result' 'resume'
#  'return' 'reveal' 'rhythm' 'right' 'room' 'rule' 'saturation' 'sc'
#  'scale' 'schedule' 'secondary' 'see' 'send' 'serious' 'service' 'setting'
#  'several' 'severe' 'she' 'shortness' 'should' 'show' 'sign' 'significant'
#  'simvastatin' 'since' 'sinus' 'sit' 'sleep' 'slide' 'slow' 'small' 'so'
#  'sob' 'social' 'sodium' 'soft' 'some' 'sound' 'st' 'stable' 'start'
#  'state' 'status' 'stay' 'stenosis' 'stent' 'stomach' 'stool' 'stop'
#  'study' 'subcutaneously' 'subsequently' 'sugar' 'sulfate' 'summary'
#  'surgery' 'symptom' 'system' 'systolic' 'tab' 'tablet' 'take'
#  'temperature' 'test' 'than' 'that' 'the' 'then' 'therapeutic' 'therapy'
#  'there' 'these' 'they' 'think' 'this' 'three' 'throughout' 'tid' 'time'
#  'to' 'today' 'tolerate' 'toprol' 'torsemide' 'total' 'transfer'
#  'transplant' 'treat' 'treatment' 'troponin' 'tube' 'twice' 'two' 'type'
#  'undergo' 'unit' 'unless' 'until' 'up' 'upon' 'upper' 'urine' 'use'
#  'valve' 'vancomycin' 'vascular' 'venous' 'ventricular' 'very' 'vital'
#  'vitamin' 'vna' 'volume' 'walk' 'wall' 'warfarin' 'wave' 'we' 'week'
#  'weight' 'well' 'when' 'where' 'which' 'while' 'white' 'who' 'will'
#  'with' 'within' 'without' 'work' 'worsen' 'would' 'wound' 'xl' 'year'
#  'yes' 'you' 'your' 'zocor'] (246, 600) (246,)
# (221, 600) (221,) (25, 600) (25,)
# (221, 600) (221,) (25, 600) (25,)
# (221, 600) (221,) (25, 600) (25,)
# (221, 600) (221,) (25, 600) (25,)
# (221, 600) (221,) (25, 600) (25,)
# (221, 600) (221,) (25, 600) (25,)
# (222, 600) (222,) (24, 600) (24,)
# (222, 600) (222,) (24, 600) (24,)
# (222, 600) (222,) (24, 600) (24,)
# (222, 600) (222,) (24, 600) (24,)
# Macro F1 score: 0.792593781268289 and Micro F1 Score 0.9716666666666667
# The shape of df is (86, 3)
# The shape of df is (72, 3)
# ['abd' 'abdominal' 'above' 'ace' 'acid' 'activity' 'acute' 'add'
#  'addition' 'additional' 'admission' 'admit' 'advair' 'afebrile' 'affect'
#  'after' 'ago' 'air' 'albuterol' 'alcohol' 'alert' 'all' 'allergy' 'also'
#  'am' 'an' 'and' 'anemia' 'antibiotic' 'anxiety' 'any' 'apnea' 'appear'
#  'applicable' 'appointment' 'approximate' 'approximately' 'area' 'artery'
#  'as' 'asa' 'aspirin' 'associate' 'asthma' 'at' 'atenolol' 'ativan'
#  'atrial' 'attend' 'avoid' 'aware' 'back' 'baseline' 'be' 'bedtime'
#  'before' 'begin' 'bid' 'bilateral' 'bilaterally' 'bleed' 'blood' 'both'
#  'bowel' 'bp' 'breast' 'breath' 'brief' 'bs' 'bun' 'but' 'by' 'cad'
#  'calcium' 'call' 'cancer' 'captopril' 'cardiac' 'cardiomyopathy'
#  'cardiovascular' 'care' 'cath' 'catheterization' 'cause' 'cc' 'celexa'
#  'cell' 'cellulitis' 'center' 'change' 'check' 'chest' 'chf' 'chill'
#  'chloride' 'chronic' 'clear' 'clinic' 'cm' 'coat' 'code' 'colace' 'come'
#  'comment' 'complaint' 'complete' 'complication' 'concern' 'condition'
#  'congestive' 'consider' 'consistent' 'constipation' 'consult'
#  'contingent' 'continue' 'control' 'copd' 'coronary' 'cough' 'coumadin'
#  'count' 'course' 'cp' 'cr' 'creatinine' 'ct' 'culture' 'cv' 'cxr' 'daily'
#  'date' 'datum' 'day' 'decrease' 'demonstrate' 'deny' 'depression'
#  'develop' 'diabete' 'diabetes' 'diagnosis' 'diarrhea' 'diastolic'
#  'dictate' 'dictation' 'diet' 'digoxin' 'dis' 'discharge' 'discontinue'
#  'disease' 'disposition' 'diurese' 'diuresis' 'dm' 'do' 'doctor'
#  'document' 'dose' 'dr' 'draw' 'drug' 'dry' 'due' 'duration' 'during'
#  'dvt' 'dysfunction' 'dyspnea' 'each' 'echo' 'echocardiogram' 'ed' 'edema'
#  'ef' 'effusion' 'ejection' 'ekg' 'elevate' 'elevated' 'emergency' 'empty'
#  'end' 'endocrine' 'enter' 'enteric' 'enzyme' 'episode' 'erythema'
#  'escription' 'evaluate' 'evaluation' 'every' 'evidence' 'exacerbation'
#  'exam' 'examination' 'exercise' 'extremity' 'failure' 'family' 'fat'
#  'feel' 'female' 'fever' 'fibrillation' 'final' 'find' 'fluid' 'follow'
#  'followup' 'food' 'foot' 'for' 'fraction' 'from' 'full' 'function'
#  'further' 'general' 'gerd' 'gi' 'give' 'go' 'good' 'gout' 'graft' 'gram'
#  'grapefruit' 'great' 'have' 'hcl' 'hct' 'he' 'head' 'headache' 'heart'
#  'heent' 'hematocrit' 'heme' 'heparin' 'her' 'high' 'his' 'history' 'hold'
#  'home' 'hospital' 'hospitalization' 'hour' 'house' 'however' 'hpi' 'hr'
#  'htn' 'hx' 'hypertension' 'hypothyroidism' 'if' 'ii' 'illness' 'improve'
#  'in' 'include' 'increase' 'infection' 'information' 'inh' 'inhaler'
#  'initially' 'inr' 'instruct' 'instruction' 'insulin' 'intact'
#  'interaction' 'iron' 'ischemia' 'issue' 'it' 'iv' 'jvp' 'knee' 'know'
#  'lab' 'laboratory' 'lad' 'lasix' 'last' 'leave' 'left' 'lesion' 'less'
#  'levofloxacin' 'likely' 'lisinopril' 'liter' 'live' 'lobe' 'lopressor'
#  'loss' 'lovenox' 'low' 'lung' 'maintain' 'make' 'management' 'may' 'mcg'
#  'md' 'meal' 'med' 'medical' 'medication' 'mellitus' 'mental' 'metoprolol'
#  'mg' 'mi' 'mibi' 'mid' 'mild' 'monitor' 'morbid' 'more' 'mouth' 'mr'
#  'multiple' 'murmur' 'myocardial' 'nasal' 'nausea' 'neck' 'need' 'neg'
#  'negative' 'neuro' 'new' 'nexium' 'nitroglycerin' 'no' 'non' 'none'
#  'nontender' 'normal' 'not' 'notable' 'note' 'notice' 'now' 'nph' 'number'
#  'obese' 'obesity' 'obtain' 'of' 'old' 'on' 'once' 'one' 'only'
#  'operation' 'or' 'order' 'osa' 'other' 'otherwise' 'out' 'outpatient'
#  'outpt' 'over' 'overridden' 'override' 'oxycodone' 'oxygen' 'pain' 'past'
#  'patient' 'pcp' 'pe' 'penicillin' 'per' 'perform' 'peripheral' 'physical'
#  'physician' 'place' 'placement' 'plan' 'plavix' 'please' 'pm' 'pneumonia'
#  'po' 'point' 'positive' 'possible' 'post' 'postoperative' 'potassium'
#  'potentially' 'prednisone' 'present' 'pressure' 'previous' 'primary'
#  'principal' 'prior' 'prn' 'problem' 'procedure' 'prophylaxis' 'psych'
#  'pt' 'puff' 'pulm' 'pulmonary' 'pulse' 'pump' 'qd' 'qhs' 'qid' 'question'
#  'ra' 'rate' 'ray' 'reaction' 'reason' 'receive' 'recent' 'recently'
#  'recommend' 'recurrent' 'ref' 'regiman' 'regimen' 'regular' 'rehab'
#  'rehabilitation' 'release' 'remain' 'renal' 'repeat' 'report' 'require'
#  'resolve' 'respiratory' 'responsible' 'restart' 'result' 'resume'
#  'return' 'reveal' 'rhythm' 'right' 'room' 'rrr' 'rule' 'saturation' 'sc'
#  'scale' 'schedule' 'secondary' 'see' 'send' 'serious' 'service' 'set'
#  'setting' 'several' 'severe' 'she' 'shortness' 'should' 'show' 'sign'
#  'significant' 'simvastatin' 'since' 'sinus' 'sit' 'skin' 'sleep' 'slide'
#  'small' 'so' 'sob' 'social' 'sodium' 'soft' 'some' 'sound' 'st' 'stable'
#  'stage' 'start' 'state' 'status' 'stay' 'stent' 'stomach' 'stool' 'study'
#  'subcutaneously' 'subsequently' 'sugar' 'sulfa' 'sulfate' 'summary'
#  'surgery' 'symptom' 'syndrome' 'system' 'systolic' 'tab' 'tablet' 'take'
#  'taper' 'tel' 'temperature' 'tenderness' 'test' 'than' 'that' 'the'
#  'then' 'therapy' 'there' 'these' 'think' 'this' 'three' 'throughout'
#  'tid' 'time' 'to' 'today' 'tolerate' 'topical' 'toprol' 'torsemide'
#  'total' 'tract' 'transfer' 'treat' 'treatment' 'tube' 'twice' 'two'
#  'tylenol' 'type' 'ulcer' 'undergo' 'unit' 'unless' 'until' 'up' 'upon'
#  'upper' 'urinary' 'urine' 'use' 'uti' 'vancomycin' 'vascular'
#  'ventricular' 'vital' 'vna' 'volume' 'vomiting' 'vs' 'wall' 'warfarin'
#  'we' 'weakness' 'week' 'weight' 'well' 'when' 'which' 'while' 'white'
#  'who' 'will' 'with' 'within' 'without' 'woman' 'work' 'would' 'wound'
#  'xl' 'year' 'yes' 'yo' 'you' 'your' 'zocor' 'zoloft'] (86, 600) (86,)
# (77, 600) (77,) (9, 600) (9,)
# (77, 600) (77,) (9, 600) (9,)
# (77, 600) (77,) (9, 600) (9,)
# (77, 600) (77,) (9, 600) (9,)
# (77, 600) (77,) (9, 600) (9,)
# (77, 600) (77,) (9, 600) (9,)
# (78, 600) (78,) (8, 600) (8,)
# (78, 600) (78,) (8, 600) (8,)
# (78, 600) (78,) (8, 600) (8,)
# (78, 600) (78,) (8, 600) (8,)
# Macro F1 score: 1.0 and Micro F1 Score 1.0
# The shape of df is (411, 3)
# The shape of df is (350, 3)
# ['abd' 'abdoman' 'abdomen' 'abdominal' 'above' 'ace' 'activity' 'acute'
#  'ada' 'add' 'addition' 'additional' 'admission' 'admit' 'afebrile'
#  'affect' 'after' 'ago' 'air' 'albuterol' 'alcohol' 'alert' 'all'
#  'allergy' 'also' 'am' 'amiodarone' 'an' 'and' 'anemia' 'angina'
#  'anterior' 'antibiotic' 'any' 'aortic' 'appear' 'applicable'
#  'appointment' 'approximate' 'approximately' 'arm' 'artery' 'as' 'asa'
#  'aspirin' 'asthma' 'at' 'atenolol' 'atorvastatin' 'atrial' 'attend'
#  'avoid' 'aware' 'back' 'baseline' 'batch' 'be' 'because' 'before' 'begin'
#  'bid' 'bilateral' 'bilaterally' 'bleed' 'block' 'blood' 'both' 'bowel'
#  'bp' 'breath' 'brief' 'bruit' 'bs' 'bun' 'but' 'by' 'bypass' 'cabg' 'cad'
#  'calcium' 'call' 'captopril' 'cardiac' 'cardiologist' 'cardiology'
#  'cardiomyopathy' 'cardiovascular' 'care' 'carotid' 'cath'
#  'catheterization' 'cause' 'cc' 'cell' 'center' 'change' 'check' 'chest'
#  'chf' 'chill' 'chloride' 'cholesterol' 'chronic' 'ck' 'clear' 'clinic'
#  'cm' 'coat' 'code' 'colace' 'comment' 'complete' 'complication' 'concern'
#  'condition' 'congestive' 'consistent' 'consult' 'contingent' 'continue'
#  'control' 'coronary' 'cough' 'coumadin' 'count' 'course' 'cp'
#  'creatinine' 'ct' 'culture' 'cv' 'cxr' 'daily' 'date' 'datum' 'day'
#  'decrease' 'demonstrate' 'deny' 'dependent' 'depression' 'descend'
#  'develop' 'diabete' 'diabetes' 'diagnosis' 'diarrhea' 'dictate'
#  'dictation' 'diet' 'digoxin' 'dis' 'discharge' 'discontinue' 'disease'
#  'disposition' 'distal' 'distress' 'diurese' 'diuresis' 'dm' 'do' 'doctor'
#  'document' 'dose' 'down' 'dr' 'draw' 'drop' 'drug' 'dry' 'due' 'during'
#  'dyspnea' 'echo' 'echocardiogram' 'ed' 'edema' 'ef' 'effusion' 'ejection'
#  'ekg' 'elevate' 'elevated' 'emergency' 'empty' 'end' 'enter' 'enteric'
#  'enzyme' 'episode' 'escription' 'evaluate' 'evaluation' 'every'
#  'evidence' 'exacerbation' 'exam' 'examination' 'exercise' 'extremity'
#  'failure' 'family' 'fat' 'feel' 'female' 'fever' 'fibrillation' 'find'
#  'first' 'floor' 'fluid' 'follow' 'food' 'foot' 'for' 'four' 'fraction'
#  'from' 'full' 'function' 'further' 'general' 'get' 'gi' 'give' 'glucose'
#  'glyburide' 'go' 'goal' 'good' 'graft' 'gram' 'grapefruit' 'great' 'have'
#  'hcl' 'hct' 'he' 'heart' 'heent' 'hematocrit' 'heparin' 'her' 'high'
#  'his' 'history' 'hold' 'home' 'hospital' 'hospitalization' 'hour' 'house'
#  'however' 'hr' 'htn' 'human' 'hypercholesterolemia' 'hypertension' 'if'
#  'ii' 'illness' 'improve' 'in' 'include' 'increase' 'index' 'infarction'
#  'infection' 'information' 'initially' 'inr' 'instruct' 'instruction'
#  'insufficiency' 'insulin' 'intact' 'interaction' 'iron' 'ischemia'
#  'ischemic' 'it' 'iv' 'jvp' 'knee' 'know' 'lab' 'laboratory' 'lad'
#  'lantus' 'lasix' 'last' 'leave' 'left' 'leg' 'lesion' 'less' 'level'
#  'levofloxacin' 'likely' 'limit' 'lipitor' 'lisinopril' 'liter' 'live'
#  'lopressor' 'lovenox' 'low' 'lung' 'maintain' 'make' 'male' 'management'
#  'may' 'mcg' 'md' 'meal' 'med' 'medical' 'medication' 'mellitus'
#  'metformin' 'metoprolol' 'mg' 'mi' 'mibi' 'mid' 'mild' 'minute' 'mitral'
#  'monitor' 'month' 'more' 'morning' 'most' 'mouth' 'mr' 'multiple'
#  'murmur' 'myocardial' 'nausea' 'neck' 'need' 'negative' 'neuro' 'new'
#  'nexium' 'next' 'night' 'nitroglycerin' 'no' 'non' 'none' 'normal' 'not'
#  'notable' 'note' 'notice' 'novolog' 'now' 'nph' 'number' 'obese'
#  'obesity' 'obtain' 'of' 'off' 'old' 'on' 'once' 'one' 'only' 'operation'
#  'or' 'order' 'orthopnea' 'other' 'otherwise' 'out' 'outpatient' 'over'
#  'overload' 'overridden' 'override' 'oxygen' 'pain' 'past' 'patient' 'pcp'
#  'pe' 'pende' 'per' 'perform' 'peripheral' 'physical' 'physician' 'place'
#  'plan' 'platelet' 'plavix' 'please' 'pm' 'pneumonia' 'po' 'poor'
#  'positive' 'possible' 'post' 'posterior' 'postoperative' 'potassium'
#  'potentially' 'prednisone' 'present' 'pressure' 'previous' 'primary'
#  'principal' 'prior' 'prn' 'problem' 'procedure' 'proximal' 'pt' 'puff'
#  'pulmonary' 'pulse' 'qam' 'qd' 'qhs' 'qpm' 'range' 'rate' 'ray' 'rca'
#  'reason' 'receive' 'recent' 'ref' 'regiman' 'regimen' 'regular'
#  'rehabilitation' 'release' 'remain' 'renal' 'repeat' 'report' 'require'
#  'resolve' 'respiratory' 'responsible' 'rest' 'restart' 'result' 'resume'
#  'return' 'reveal' 'rhythm' 'right' 'risk' 'room' 'rule' 'saturation' 'sc'
#  'scale' 'schedule' 'secondary' 'see' 'send' 'serious' 'service' 'setting'
#  'several' 'severe' 'she' 'shortness' 'should' 'show' 'sign' 'significant'
#  'simvastatin' 'since' 'sinus' 'sit' 'sleep' 'slide' 'small' 'so' 'sob'
#  'social' 'sodium' 'soft' 'some' 'sound' 'st' 'stable' 'start' 'state'
#  'status' 'stay' 'stenosis' 'stent' 'stomach' 'stool' 'stop' 'study'
#  'subcutaneously' 'sugar' 'summary' 'surgery' 'surgical' 'symptom'
#  'system' 'systolic' 'tab' 'tablet' 'take' 'temperature' 'tenderness'
#  'test' 'than' 'that' 'the' 'then' 'therapy' 'there' 'these' 'they'
#  'think' 'this' 'three' 'through' 'throughout' 'tid' 'time' 'to' 'today'
#  'tolerate' 'toprol' 'total' 'transfer' 'treat' 'treatment' 'troponin'
#  'tube' 'twice' 'two' 'type' 'ulcer' 'undergo' 'unit' 'unless' 'until'
#  'up' 'upon' 'upper' 'urinary' 'urine' 'use' 'valve' 'vancomycin'
#  'vascular' 'venous' 'ventricular' 'very' 'vessel' 'vital' 'vitamin'
#  'volume' 'vomiting' 'walk' 'wall' 'warfarin' 'wave' 'we' 'week' 'weight'
#  'well' 'when' 'where' 'which' 'while' 'white' 'who' 'will' 'with'
#  'within' 'without' 'woman' 'work' 'worsen' 'would' 'wound' 'xl' 'year'
#  'yes' 'you' 'your' 'zocor'] (411, 600) (411,)
# (369, 600) (369,) (42, 600) (42,)
# (370, 600) (370,) (41, 600) (41,)
# (370, 600) (370,) (41, 600) (41,)
# (370, 600) (370,) (41, 600) (41,)
# (370, 600) (370,) (41, 600) (41,)
# (370, 600) (370,) (41, 600) (41,)
# (370, 600) (370,) (41, 600) (41,)
# (370, 600) (370,) (41, 600) (41,)
# (370, 600) (370,) (41, 600) (41,)
# (370, 600) (370,) (41, 600) (41,)
# Macro F1 score: 0.6424667616334283 and Micro F1 Score 0.9707317073170731
# The shape of df is (94, 3)
# The shape of df is (89, 3)
# ['abd' 'abdoman' 'abdomen' 'abdominal' 'above' 'acid' 'activity' 'acute'
#  'ada' 'add' 'additional' 'admission' 'admit' 'afebrile' 'affect' 'after'
#  'again' 'air' 'alcohol' 'alert' 'all' 'allergy' 'also' 'am' 'an' 'and'
#  'anemia' 'angina' 'anterior' 'antibiotic' 'any' 'aortic' 'appointment'
#  'approximately' 'area' 'artery' 'as' 'asa' 'aspirin' 'asthma' 'at'
#  'atenolol' 'atorvastatin' 'atrial' 'attend' 'august' 'avoid' 'aware'
#  'back' 'bactrim' 'baseline' 'batch' 'be' 'because' 'before' 'begin' 'bid'
#  'bilateral' 'bilaterally' 'block' 'blood' 'both' 'bowel' 'breath' 'brief'
#  'bruit' 'bs' 'bun' 'but' 'by' 'bypass' 'cabg' 'cad' 'calcium' 'call'
#  'cardiac' 'cardiologist' 'cardiology' 'cardiovascular' 'care' 'carotid'
#  'catheterization' 'cause' 'cc' 'cell' 'center' 'change' 'check' 'chest'
#  'chf' 'chill' 'chloride' 'cholecystectomy' 'cholesterol' 'chronic'
#  'clear' 'clinic' 'cm' 'code' 'colace' 'comment' 'complete' 'complication'
#  'condition' 'congestive' 'consider' 'consistent' 'consult' 'contingent'
#  'continue' 'control' 'copd' 'coronary' 'cough' 'coumadin' 'count'
#  'course' 'crackle' 'creatinine' 'ct' 'culture' 'daily' 'date' 'datum'
#  'day' 'decrease' 'demonstrate' 'deny' 'dependent' 'depression' 'descend'
#  'develop' 'diabete' 'diabetes' 'diagnosis' 'diarrhea' 'dictate'
#  'dictation' 'diet' 'digoxin' 'dis' 'discharge' 'discontinue' 'disease'
#  'disposition' 'distal' 'distress' 'diuresis' 'dm' 'do' 'doctor'
#  'document' 'dose' 'down' 'dr' 'draw' 'drug' 'dry' 'due' 'during' 'dvt'
#  'dyspnea' 'echo' 'echocardiogram' 'ed' 'edema' 'ef' 'effusion' 'ejection'
#  'ekg' 'elevate' 'emergency' 'end' 'endocrine' 'enter' 'enzyme' 'episode'
#  'escription' 'evaluate' 'evaluation' 'every' 'evidence' 'exam'
#  'examination' 'exercise' 'extremity' 'failure' 'family' 'fat' 'feel'
#  'female' 'fever' 'fibrillation' 'find' 'first' 'flagyl' 'fluid' 'follow'
#  'followup' 'food' 'foot' 'for' 'four' 'fraction' 'free' 'from' 'full'
#  'function' 'further' 'gallbladder' 'gallstone' 'general' 'gerd' 'get'
#  'gi' 'give' 'glucose' 'go' 'good' 'gout' 'graft' 'gram' 'great' 'have'
#  'hcl' 'he' 'headache' 'health' 'heart' 'heent' 'hematocrit' 'heparin'
#  'her' 'hernia' 'high' 'his' 'history' 'hold' 'home' 'hospital'
#  'hospitalization' 'hour' 'house' 'however' 'htn' 'hypercholesterolemia'
#  'hypertension' 'hypothyroidism' 'if' 'ii' 'illness' 'imdur' 'improve'
#  'in' 'include' 'increase' 'index' 'infarction' 'infection' 'infectious'
#  'inferior' 'information' 'initially' 'inr' 'instruct' 'instruction'
#  'insufficiency' 'insulin' 'intact' 'interaction' 'iron' 'ischemia'
#  'isordil' 'it' 'iv' 'jvp' 'knee' 'know' 'lab' 'laboratory' 'lad' 'lantus'
#  'lasix' 'last' 'lead' 'leave' 'left' 'leg' 'lesion' 'less' 'level'
#  'levofloxacin' 'likely' 'limit' 'lipitor' 'lisinopril' 'liter' 'live'
#  'liver' 'long' 'lopressor' 'lovenox' 'low' 'lung' 'magnesium' 'maintain'
#  'make' 'management' 'may' 'mcg' 'md' 'meal' 'med' 'medical' 'medication'
#  'mellitus' 'mental' 'meq' 'mg' 'mi' 'mibi' 'mid' 'mild' 'milligram'
#  'milligrams' 'minute' 'mitral' 'monitor' 'month' 'more' 'most' 'mouth'
#  'mr' 'multiple' 'murmur' 'myocardial' 'nausea' 'nebulizer' 'neck' 'need'
#  'negative' 'new' 'nexium' 'night' 'nitroglycerin' 'no' 'non' 'none'
#  'nontender' 'normal' 'not' 'notable' 'note' 'notice' 'now' 'nph' 'number'
#  'obese' 'obesity' 'of' 'old' 'on' 'once' 'one' 'only' 'operation' 'or'
#  'oral' 'order' 'other' 'otherwise' 'out' 'outpatient' 'over' 'overload'
#  'overridden' 'override' 'oxycodone' 'oxygen' 'pack' 'pain' 'pancreatitis'
#  'past' 'patient' 'pcp' 'pda' 'penicillin' 'per' 'percent' 'perform'
#  'peripheral' 'physical' 'physician' 'place' 'placement' 'plan' 'platelet'
#  'plavix' 'please' 'pm' 'pneumonia' 'po' 'poor' 'positive' 'possible'
#  'post' 'posterior' 'postoperative' 'potassium' 'potentially' 'prednisone'
#  'present' 'pressure' 'previous' 'primary' 'principal' 'prior' 'prn'
#  'problem' 'procedure' 'prophylaxis' 'pt' 'ptca' 'pulmonary' 'pulse' 'qd'
#  'qpm' 'quadrant' 'question' 'rate' 'ray' 'reason' 'receive' 'recent'
#  'recently' 'recommend' 'ref' 'regiman' 'regimen' 'regular'
#  'regurgitation' 'rehab' 'rehabilitation' 'remain' 'renal' 'repeat'
#  'replacement' 'report' 'require' 'resolve' 'respiratory' 'responsible'
#  'restart' 'result' 'resume' 'return' 'reveal' 'rhythm' 'right' 'room'
#  'rule' 'saphenous' 'saturation' 'sc' 'scale' 'scan' 'schedule' 'second'
#  'secondary' 'see' 'send' 'serious' 'service' 'several' 'severe' 'she'
#  'shortness' 'should' 'show' 'sign' 'significant' 'simvastatin' 'since'
#  'sinus' 'sit' 'six' 'sleep' 'slide' 'small' 'sob' 'social' 'sodium'
#  'soft' 'some' 'sound' 'st' 'stable' 'start' 'state' 'status' 'stay'
#  'stenosis' 'stent' 'stone' 'stool' 'stop' 'study' 'subcutaneously'
#  'sugar' 'summary' 'surgery' 'surgical' 'symptom' 'synthroid' 'systolic'
#  'tab' 'tablet' 'take' 'taper' 'temperature' 'tenderness' 'test' 'than'
#  'that' 'the' 'then' 'therapy' 'there' 'therefore' 'these' 'they' 'think'
#  'this' 'three' 'through' 'throughout' 'time' 'to' 'today' 'tolerate'
#  'toprol' 'total' 'tract' 'transfer' 'treat' 'treatment' 'tube' 'twice'
#  'two' 'tylenol' 'ulcer' 'ultrasound' 'undergo' 'unit' 'unsigned' 'until'
#  'up' 'upon' 'upper' 'urinary' 'urine' 'use' 'valve' 'vancomycin'
#  'vascular' 'vein' 'ventricular' 'vital' 'vitamin' 'volume' 'vomiting'
#  'walk' 'wall' 'warfarin' 'wave' 'we' 'week' 'weight' 'well' 'wheeze'
#  'when' 'where' 'which' 'while' 'white' 'who' 'will' 'with' 'within'
#  'without' 'woman' 'work' 'would' 'wound' 'xl' 'year' 'yes' 'you' 'your'
#  'zocor'] (94, 600) (94,)
# (84, 600) (84,) (10, 600) (10,)
# (84, 600) (84,) (10, 600) (10,)
# (84, 600) (84,) (10, 600) (10,)
# (84, 600) (84,) (10, 600) (10,)
# (85, 600) (85,) (9, 600) (9,)
# (85, 600) (85,) (9, 600) (9,)
# (85, 600) (85,) (9, 600) (9,)
# (85, 600) (85,) (9, 600) (9,)
# (85, 600) (85,) (9, 600) (9,)
# (85, 600) (85,) (9, 600) (9,)
# Macro F1 score: 0.841795665634675 and Micro F1 Score 0.9688888888888888
# The shape of df is (99, 3)
# The shape of df is (70, 3)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[25], line 14
#      11 train_preprocessed_df = dataPreprocessing.preprocess_data()
#      13 dataPreprocessing = DataPreprocessing('./dataset/test/test_data_textual.csv', morbidity)
# ---> 14 test_preprocessed_df = dataPreprocessing.preprocess_data()
#      16 X, Y, words = TFIDFFeatureGeneration(train_preprocessed_df, morbidity).tf_idf_matrix_gen()
#      18 # add KFold cross validation
#
# File ~/Documents/GitHub/CS598_DLH_Project/dataset/preprocessing/data_preprocessing.py:44, in DataPreprocessing.preprocess_data(self)
#      42 def preprocess_data(self):
#      43     self.df = self.df.apply(self.to_lower_case, axis=1)
# ---> 44     self.df = self.df.apply(self.tokenize, axis=1)
#      45     self.df = self.df.apply(self.remove_punctuation_and_numeric_values, axis=1)
#      46     self.df = self.df.apply(self.lemmatization, axis=1)
#
# File ~/Library/Python/3.8/lib/python/site-packages/pandas/core/frame.py:9428, in DataFrame.apply(self, func, axis, raw, result_type, args, **kwargs)
#    9417 from pandas.core.apply import frame_apply
#    9419 op = frame_apply(
#    9420     self,
#    9421     func=func,
#    (...)
#    9426     kwargs=kwargs,
#    9427 )
# -> 9428 return op.apply().__finalize__(self, method="apply")
#
# File ~/Library/Python/3.8/lib/python/site-packages/pandas/core/apply.py:678, in FrameApply.apply(self)
#     675 elif self.raw:
#     676     return self.apply_raw()
# --> 678 return self.apply_standard()
#
# File ~/Library/Python/3.8/lib/python/site-packages/pandas/core/apply.py:798, in FrameApply.apply_standard(self)
#     797 def apply_standard(self):
# --> 798     results, res_index = self.apply_series_generator()
#     800     # wrap results
#     801     return self.wrap_results(results, res_index)
#
# File ~/Library/Python/3.8/lib/python/site-packages/pandas/core/apply.py:814, in FrameApply.apply_series_generator(self)
#     811 with option_context("mode.chained_assignment", None):
#     812     for i, v in enumerate(series_gen):
#     813         # ignore SettingWithCopy here in case the user mutates
# --> 814         results[i] = self.f(v)
#     815         if isinstance(results[i], ABCSeries):
#     816             # If we have a view on v, we need to make a copy because
#     817             #  series_generator will swap out the underlying data
#     818             results[i] = results[i].copy(deep=False)
#
# File ~/Documents/GitHub/CS598_DLH_Project/dataset/preprocessing/data_preprocessing.py:18, in DataPreprocessing.tokenize(self, row)
#      17 def tokenize(self, row):
# ---> 18     row[1] = self.nlp(row[1])
#      19     return row
#
# File ~/Library/Python/3.8/lib/python/site-packages/spacy/language.py:1011, in Language.__call__(self, text, disable, component_cfg)
#    1009     error_handler = proc.get_error_handler()
#    1010 try:
# -> 1011     doc = proc(doc, **component_cfg.get(name, {}))  # type: ignore[call-arg]
#    1012 except KeyError as e:
#    1013     # This typically happens if a component is not initialized
#    1014     raise ValueError(Errors.E109.format(name=name)) from e
#
# File ~/Library/Python/3.8/lib/python/site-packages/spacy/pipeline/trainable_pipe.pyx:52, in spacy.pipeline.trainable_pipe.TrainablePipe.__call__()
#
# File ~/Library/Python/3.8/lib/python/site-packages/spacy/pipeline/transition_parser.pyx:253, in spacy.pipeline.transition_parser.Parser.predict()
#
# File ~/Library/Python/3.8/lib/python/site-packages/spacy/pipeline/transition_parser.pyx:274, in spacy.pipeline.transition_parser.Parser.greedy_parse()
#
# File ~/Library/Python/3.8/lib/python/site-packages/thinc/model.py:315, in Model.predict(self, X)
#     311 def predict(self, X: InT) -> OutT:
#     312     """Call the model's `forward` function with `is_train=False`, and return
#     313     only the output, instead of the `(output, callback)` tuple.
#     314     """
# --> 315     return self._func(self, X, is_train=False)[0]
#
# File ~/Library/Python/3.8/lib/python/site-packages/spacy/ml/tb_framework.py:33, in forward(model, X, is_train)
#      32 def forward(model, X, is_train):
# ---> 33     step_model = ParserStepModel(
#      34         X,
#      35         model.layers,
#      36         unseen_classes=model.attrs["unseen_classes"],
#      37         train=is_train,
#      38         has_upper=model.attrs["has_upper"],
#      39     )
#      41     return step_model, step_model.finish_steps
#
# File ~/Library/Python/3.8/lib/python/site-packages/spacy/ml/parser_model.pyx:213, in spacy.ml.parser_model.ParserStepModel.__init__()
#
# File ~/Library/Python/3.8/lib/python/site-packages/thinc/model.py:291, in Model.__call__(self, X, is_train)
#     288 def __call__(self, X: InT, is_train: bool) -> Tuple[OutT, Callable]:
#     289     """Call the model's `forward` function, returning the output and a
#     290     callback to compute the gradients via backpropagation."""
# --> 291     return self._func(self, X, is_train=is_train)
#
# File ~/Library/Python/3.8/lib/python/site-packages/thinc/layers/chain.py:55, in forward(model, X, is_train)
#      53 callbacks = []
#      54 for layer in model.layers:
# ---> 55     Y, inc_layer_grad = layer(X, is_train=is_train)
#      56     callbacks.append(inc_layer_grad)
#      57     X = Y
#
# File ~/Library/Python/3.8/lib/python/site-packages/thinc/model.py:291, in Model.__call__(self, X, is_train)
#     288 def __call__(self, X: InT, is_train: bool) -> Tuple[OutT, Callable]:
#     289     """Call the model's `forward` function, returning the output and a
#     290     callback to compute the gradients via backpropagation."""
# --> 291     return self._func(self, X, is_train=is_train)
#
# File ~/Library/Python/3.8/lib/python/site-packages/thinc/layers/chain.py:55, in forward(model, X, is_train)
#      53 callbacks = []
#      54 for layer in model.layers:
# ---> 55     Y, inc_layer_grad = layer(X, is_train=is_train)
#      56     callbacks.append(inc_layer_grad)
#      57     X = Y
#
# File ~/Library/Python/3.8/lib/python/site-packages/thinc/model.py:291, in Model.__call__(self, X, is_train)
#     288 def __call__(self, X: InT, is_train: bool) -> Tuple[OutT, Callable]:
#     289     """Call the model's `forward` function, returning the output and a
#     290     callback to compute the gradients via backpropagation."""
# --> 291     return self._func(self, X, is_train=is_train)
#
# File ~/Library/Python/3.8/lib/python/site-packages/thinc/layers/with_array.py:38, in forward(model, Xseq, is_train)
#      36     return model.layers[0](Xseq, is_train)
#      37 else:
# ---> 38     return cast(Tuple[SeqT, Callable], _list_forward(model, Xseq, is_train))
#
# File ~/Library/Python/3.8/lib/python/site-packages/thinc/layers/with_array.py:73, in _list_forward(model, Xs, is_train)
#      71 lengths = layer.ops.asarray1i([len(seq) for seq in Xs])
#      72 Xf = layer.ops.flatten(Xs, pad=pad)
# ---> 73 Yf, get_dXf = layer(Xf, is_train)
#      75 def backprop(dYs: ListXd) -> ListXd:
#      76     dYf = layer.ops.flatten(dYs, pad=pad)
#
# File ~/Library/Python/3.8/lib/python/site-packages/thinc/model.py:291, in Model.__call__(self, X, is_train)
#     288 def __call__(self, X: InT, is_train: bool) -> Tuple[OutT, Callable]:
#     289     """Call the model's `forward` function, returning the output and a
#     290     callback to compute the gradients via backpropagation."""
# --> 291     return self._func(self, X, is_train=is_train)
#
# File ~/Library/Python/3.8/lib/python/site-packages/thinc/layers/chain.py:55, in forward(model, X, is_train)
#      53 callbacks = []
#      54 for layer in model.layers:
# ---> 55     Y, inc_layer_grad = layer(X, is_train=is_train)
#      56     callbacks.append(inc_layer_grad)
#      57     X = Y
#
# File ~/Library/Python/3.8/lib/python/site-packages/thinc/model.py:291, in Model.__call__(self, X, is_train)
#     288 def __call__(self, X: InT, is_train: bool) -> Tuple[OutT, Callable]:
#     289     """Call the model's `forward` function, returning the output and a
#     290     callback to compute the gradients via backpropagation."""
# --> 291     return self._func(self, X, is_train=is_train)
#
# File ~/Library/Python/3.8/lib/python/site-packages/thinc/layers/residual.py:41, in forward(model, X, is_train)
#      38     else:
#      39         return d_output + dX
# ---> 41 Y, backprop_layer = model.layers[0](X, is_train)
#      42 if isinstance(X, list):
#      43     return [X[i] + Y[i] for i in range(len(X))], backprop
#
# File ~/Library/Python/3.8/lib/python/site-packages/thinc/model.py:291, in Model.__call__(self, X, is_train)
#     288 def __call__(self, X: InT, is_train: bool) -> Tuple[OutT, Callable]:
#     289     """Call the model's `forward` function, returning the output and a
#     290     callback to compute the gradients via backpropagation."""
# --> 291     return self._func(self, X, is_train=is_train)
#
# File ~/Library/Python/3.8/lib/python/site-packages/thinc/layers/chain.py:55, in forward(model, X, is_train)
#      53 callbacks = []
#      54 for layer in model.layers:
# ---> 55     Y, inc_layer_grad = layer(X, is_train=is_train)
#      56     callbacks.append(inc_layer_grad)
#      57     X = Y
#
# File ~/Library/Python/3.8/lib/python/site-packages/thinc/model.py:291, in Model.__call__(self, X, is_train)
#     288 def __call__(self, X: InT, is_train: bool) -> Tuple[OutT, Callable]:
#     289     """Call the model's `forward` function, returning the output and a
#     290     callback to compute the gradients via backpropagation."""
# --> 291     return self._func(self, X, is_train=is_train)
#
# File ~/Library/Python/3.8/lib/python/site-packages/thinc/layers/chain.py:55, in forward(model, X, is_train)
#      53 callbacks = []
#      54 for layer in model.layers:
# ---> 55     Y, inc_layer_grad = layer(X, is_train=is_train)
#      56     callbacks.append(inc_layer_grad)
#      57     X = Y
#
#     [... skipping similar frames: Model.__call__ at line 291 (1 times)]
#
# File ~/Library/Python/3.8/lib/python/site-packages/thinc/layers/chain.py:55, in forward(model, X, is_train)
#      53 callbacks = []
#      54 for layer in model.layers:
# ---> 55     Y, inc_layer_grad = layer(X, is_train=is_train)
#      56     callbacks.append(inc_layer_grad)
#      57     X = Y
#
# File ~/Library/Python/3.8/lib/python/site-packages/thinc/model.py:291, in Model.__call__(self, X, is_train)
#     288 def __call__(self, X: InT, is_train: bool) -> Tuple[OutT, Callable]:
#     289     """Call the model's `forward` function, returning the output and a
#     290     callback to compute the gradients via backpropagation."""
# --> 291     return self._func(self, X, is_train=is_train)
#
# File ~/Library/Python/3.8/lib/python/site-packages/thinc/layers/maxout.py:53, in forward(model, X, is_train)
#      51 W = model.get_param("W")
#      52 W = model.ops.reshape2f(W, nO * nP, nI)
# ---> 53 Y = model.ops.gemm(X, W, trans2=True)
#      54 Y += model.ops.reshape1f(b, nO * nP)
#      55 Z = model.ops.reshape3f(Y, Y.shape[0], nO, nP)
#
# KeyboardInterrupt:
